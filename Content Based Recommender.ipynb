# %%
import pandas as pd
import warnings; warnings.simplefilter('ignore')

# %%
data = pd.read_csv("dataset/movies_metadata.csv")
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 4  False                                                NaN  60000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3                     [{'id': 35, 'name': 'Comedy'}]
# 4  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  11862  tt0113041                en
# 4                                   NaN    949  tt0113277                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3  Father of the Bride Part II
# 4                         Heat
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Just when George Banks has recovered from his ...  ...    1995-02-10
# 4  Obsessive master thief, Neil McCauley leads a ...  ...    1995-12-15
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4  187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Just When His World Is Back To Normal... He's ...
# 4  Released                           A Los Angeles Crime Saga
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3  Father of the Bride Part II  False          5.7      173.0
# 4                         Heat  False          7.7     1886.0
#
# [5 rows x 24 columns]

# %%
credits = pd.read_csv("dataset/credits.csv")
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'George Banks', '...
# 4  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
# 4  [{'credit_id': '52fe4292c3a36847f802916d', 'de...    949

# %%
keywords = pd.read_csv("dataset/keywords.csv")
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 4    949  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...

# %%
data = data.merge(credits, on='id')
data = data.merge(keywords, on='id')
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 4  False                                                NaN  60000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3                     [{'id': 35, 'name': 'Comedy'}]
# 4  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  11862  tt0113041                en
# 4                                   NaN    949  tt0113277                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3  Father of the Bride Part II
# 4                         Heat
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Just when George Banks has recovered from his ...  ...
# 4  Obsessive master thief, Neil McCauley leads a ...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Just When His World Is Back To Normal... He's ...
# 4                           A Los Angeles Crime Saga
#
#                          title  video  vote_average  vote_count  \
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3  Father of the Bride Part II  False           5.7       173.0
# 4                         Heat  False           7.7      1886.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'George Banks', '...
# 4  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44959251416c75039ed7', 'de...
# 4  [{'credit_id': '52fe4292c3a36847f802916d', 'de...
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 4  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
#
# [5 rows x 27 columns]

# %%
def get_genres(x):
    genre = []
    for i in x:
        genre.append(i['name'])
    return genre

# %%
def get_cast(x):
    cast = []
    num = 0
    for i in x:
        i['name'] = i['name'].replace(" ","")
        cast.append(i['name'])
        num = num + 1
        if num==5:
            break
    return cast

# %%
def get_crew(x):
    crew = []
    for i in x:
        if i['job'] == 'Director' or i['job'] =='Screenplay':
            i['name'] = i['name'].replace(" ","")
            crew.append(i['name'])
    return crew

# %%
def get_keywords(x):
    keywords = []
    for i in x:
        i['name'] = i['name'].replace(" ","")
        keywords.append(i['name'])
    return keywords

# %%
from ast import literal_eval

data['genres'] = data['genres'].apply(literal_eval).apply(get_genres)
data['cast'] = data['cast'].apply(literal_eval).apply(get_cast)
data['crew'] = data['crew'].apply(literal_eval).apply(get_crew)
data['keywords'] = data['keywords'].apply(literal_eval).apply(get_keywords)

data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 4  False                                                NaN  60000000
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# 2                 [Romance, Comedy]                                   NaN
# 3                          [Comedy]                                   NaN
# 4  [Action, Crime, Drama, Thriller]                                   NaN
#
#       id    imdb_id original_language               original_title  \
# 0    862  tt0114709                en                    Toy Story
# 1   8844  tt0113497                en                      Jumanji
# 2  15602  tt0113228                en             Grumpier Old Men
# 3  11862  tt0113041                en  Father of the Bride Part II
# 4    949  tt0113277                en                         Heat
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Just when George Banks has recovered from his ...  ...
# 4  Obsessive master thief, Neil McCauley leads a ...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Just When His World Is Back To Normal... He's ...
# 4                           A Los Angeles Crime Saga
#
#                          title  video  vote_average  vote_count  \
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3  Father of the Bride Part II  False           5.7       173.0
# 4                         Heat  False           7.7      1886.0
#
#                                                 cast  \
# 0  [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1  [RobinWilliams, JonathanHyde, KirstenDunst, Br...
# 2  [WalterMatthau, JackLemmon, Ann-Margret, Sophi...
# 3  [SteveMartin, DianeKeaton, MartinShort, Kimber...
# 4  [AlPacino, RobertDeNiro, ValKilmer, JonVoight,...
#
#                                                 crew  \
# 0  [JohnLasseter, JossWhedon, AndrewStanton, Joel...
# 1  [JonathanHensleigh, JoeJohnston, GregTaylor, J...
# 2                                     [HowardDeutch]
# 3         [NancyMeyers, AlbertHackett, CharlesShyer]
# 4                         [MichaelMann, MichaelMann]
#
#                                             keywords
# 0  [jealousy, toy, boy, friendship, friends, riva...
# 1  [boardgame, disappearance, basedonchildren'sbo...
# 2  [fishing, bestfriend, duringcreditsstinger, ol...
# 3  [baby, midlifecrisis, confidence, aging, daugh...
# 4  [robbery, detective, bank, obsession, chase, s...
#
# [5 rows x 27 columns]

# %%
data['soup'] = data['genres']+data['cast']+data['crew']+data['keywords']
data['soup'] = data['soup'].apply(lambda x: ' '.join(x))
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 4  False                                                NaN  60000000
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# 2                 [Romance, Comedy]                                   NaN
# 3                          [Comedy]                                   NaN
# 4  [Action, Crime, Drama, Thriller]                                   NaN
#
#       id    imdb_id original_language               original_title  \
# 0    862  tt0114709                en                    Toy Story
# 1   8844  tt0113497                en                      Jumanji
# 2  15602  tt0113228                en             Grumpier Old Men
# 3  11862  tt0113041                en  Father of the Bride Part II
# 4    949  tt0113277                en                         Heat
#
#                                             overview  ...    status  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  Released
# 1  When siblings Judy and Peter discover an encha...  ...  Released
# 2  A family wedding reignites the ancient feud be...  ...  Released
# 3  Just when George Banks has recovered from his ...  ...  Released
# 4  Obsessive master thief, Neil McCauley leads a ...  ...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Just When His World Is Back To Normal... He's ...
# 4                           A Los Angeles Crime Saga
#
#                          title  video vote_average  vote_count  \
# 0                    Toy Story  False          7.7      5415.0
# 1                      Jumanji  False          6.9      2413.0
# 2             Grumpier Old Men  False          6.5        92.0
# 3  Father of the Bride Part II  False          5.7       173.0
# 4                         Heat  False          7.7      1886.0
#
#                                                 cast  \
# 0  [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1  [RobinWilliams, JonathanHyde, KirstenDunst, Br...
# 2  [WalterMatthau, JackLemmon, Ann-Margret, Sophi...
# 3  [SteveMartin, DianeKeaton, MartinShort, Kimber...
# 4  [AlPacino, RobertDeNiro, ValKilmer, JonVoight,...
#
#                                                 crew  \
# 0  [JohnLasseter, JossWhedon, AndrewStanton, Joel...
# 1  [JonathanHensleigh, JoeJohnston, GregTaylor, J...
# 2                                     [HowardDeutch]
# 3         [NancyMeyers, AlbertHackett, CharlesShyer]
# 4                         [MichaelMann, MichaelMann]
#
#                                             keywords  \
# 0  [jealousy, toy, boy, friendship, friends, riva...
# 1  [boardgame, disappearance, basedonchildren'sbo...
# 2  [fishing, bestfriend, duringcreditsstinger, ol...
# 3  [baby, midlifecrisis, confidence, aging, daugh...
# 4  [robbery, detective, bank, obsession, chase, s...
#
#                                                 soup
# 0  Animation Comedy Family TomHanks TimAllen DonR...
# 1  Adventure Fantasy Family RobinWilliams Jonatha...
# 2  Romance Comedy WalterMatthau JackLemmon Ann-Ma...
# 3  Comedy SteveMartin DianeKeaton MartinShort Kim...
# 4  Action Crime Drama Thriller AlPacino RobertDeN...
#
# [5 rows x 28 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
count = CountVectorizer(analyzer='word', stop_words='english')
matrix = count.fit_transform(data['soup'])
matrix.shape
# Out:
# (9187, 38055)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(matrix,matrix)

# %%
titles = data[['title','vote_count','vote_average']]
index = pd.Series(data.index, index=data['title'])

# %%
def get_recommendation(title):
    ind = index[title]
    vote = data.iloc[ind]['vote_average']
    score = list(enumerate(similarity[ind]))
    score = sorted(score, key=lambda x: x[1], reverse=True)
    vote_min = vote - 2
    movie_indices = [i[0] for i in score]
    top = pd.DataFrame(titles.iloc[movie_indices])
    top = top[top['vote_average'] >= vote_min]
    top = top[1:]
    return top.head(10)

# %%
get_recommendation('The Godfather')
# Out:
#                          title  vote_count  vote_average
# 594     The Godfather: Part II      3418.0           8.3
# 988    The Godfather: Part III      1589.0           7.1
# 2297           The Cotton Club        71.0           6.5
# 817              The Rainmaker       239.0           6.7
# 1859          The Conversation       377.0           7.5
# 581             Apocalypse Now      2112.0           8.0
# 3647               Rumble Fish       141.0           6.8
# 4442  The Consequences of Love       125.0           7.6
# 1708    ...And Justice for All       118.0           7.1
# 1041             The Outsiders       293.0           6.9

# %%
get_recommendation('Man of Steel')
# Out:
#                                        title  vote_count  vote_average
# 7979      Batman v Superman: Dawn of Justice      7189.0           5.7
# 4246                        Superman Returns      1429.0           5.4
# 4760        Justice League: The New Frontier       115.0           6.6
# 1338                            Superman III       500.0           5.3
# 1337                             Superman II       642.0           6.5
# 7573      Justice League: Throne of Atlantis       222.0           6.5
# 6668  Justice League: The Flashpoint Paradox       458.0           7.3
# 7926                           Suicide Squad      7717.0           5.9
# 1336                                Superman      1042.0           6.9
# 1893                                   X-Men      4172.0           6.8

# %%
get_recommendation('The Prestige')
# Out:
#                       title  vote_count  vote_average
# 4766        The Dark Knight     12269.0           8.3
# 6003  The Dark Knight Rises      9263.0           7.6
# 1310              Following       363.0           7.2
# 5508              Inception     14075.0           8.1
# 7501              Doodlebug       105.0           6.6
# 7502              Doodlebug       105.0           6.6
# 3945          Batman Begins      7511.0           7.5
# 2088                Memento      4168.0           8.1
# 2828                 Spider       176.0           6.4
# 2750              Deathtrap        58.0           6.7

# %%
get_recommendation('The Dark Knight')
# Out:
#                            title  vote_count  vote_average
# 6003       The Dark Knight Rises      9263.0           7.6
# 3945               Batman Begins      7511.0           7.5
# 4339                The Prestige      4510.0           8.0
# 5517  Batman: Under the Red Hood       459.0           7.6
# 7184   Batman: Assault on Arkham       298.0           7.3
# 1310                   Following       363.0           7.2
# 709               Batman Returns      1706.0           6.6
# 3709                    Thursday        84.0           7.0
# 5433                    Defendor       197.0           6.5
# 319                       Batman      2145.0           7.0

# %%
get_recommendation('Dilwale Dulhania Le Jayenge')
# Out:
#                          title  vote_count  vote_average
# 7897          Jab Tak Hai Jaan        68.0           7.2
# 5398           My Name Is Khan       237.0           7.7
# 3541                Veer-Zaara        67.0           7.5
# 4670              Om Shanti Om        85.0           7.2
# 3772             Kal Ho Naa Ho       110.0           7.3
# 1554               Holiday Inn        55.0           7.1
# 3729                    Devdas        78.0           7.4
# 5871             Loose Cannons       122.0           7.1
# 7091               Begin Again      1285.0           7.3
# 3732  Kabhi Khushi Kabhie Gham       103.0           7.6
